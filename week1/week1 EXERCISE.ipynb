# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
system_prompt = """
You are a helpful assistant that analyzes the contents of a website,
and provides a short, pleasant summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def messages_for(website):
    """Create message list for the LLM."""
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]


def summarize(url):
    """Fetch and summarize a website using Ollama."""
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=messages_for(website)
    )
    return response.choices[0].message.content
# Get gpt-4o-mini to answer, with streaming

# %%
def main():
    """Main entry point for testing."""
    url = input("Enter a URL to summarize: ")
    print("\nFetching and summarizing...\n")
    summary = summarize(url)
    print(summary)


if __name__ == "__main__":
    main()
# Out:
# Fetching and summarizing...
#
# ### Website Summary and News
#
# This website appears to be the CNN news and entertainment portal.
#
# Summary for Non-Entertainment Content:
#
# The webpage features various topics including World, Politics, Business, Health, Entertainment, and more. The topics are further divided into US and International sections.
#
# There is no new announcement in the provided information content but there is an ongoing conflict in the "Conflict" section which spans multiple news areas like:
#
# *   Ukraine-Russia War
# *   Israel-Hamas War
